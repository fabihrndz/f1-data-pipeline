# %%
import requests
import json
# Out:
# c:\Users\fabih\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.4.3)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(

# %%
url = "https://api.jolpi.ca/ergast/f1/pitstops"

# %%
response = requests.get(url)

# %%
response.content
# Out:
# b'{"detail":"Bad Request: Missing one of the required parameters [\'season_year\', \'race_round\']."}'

# %%
data = response.json()

# %%
data
# Out:
# {'detail': "Bad Request: Missing one of the required parameters ['season_year', 'race_round']."}

# %%
data.keys()
# Out:
# dict_keys(['MRData'])

# %%
data["MRData"]["CircuitTable"]["Circuits"][0]["circuitId"]       #Ruta para el id
# Out:
# 'adelaide'

# %%
data["MRData"]["CircuitTable"]["Circuits"][0]["circuitName"]     #Ruta para el name
# Out:
# 'Adelaide Street Circuit'

# %%
data["MRData"]["CircuitTable"]["Circuits"][0]["Location"]["locality"]    #Ruta para location
# Out:
# 'Adelaide'

# %%
data["MRData"]["CircuitTable"]["Circuits"][0]["Location"]["country"]    #Ruta para country
# Out:
# 'Australia'

# %%
data["MRData"]["CircuitTable"]["Circuits"][0]["Location"]["lat"]      #Ruta para lat
# Out:
# '-34.9272'

# %%
data["MRData"]["CircuitTable"]["Circuits"][0]["Location"]["long"]    #Ruta para lng
# Out:
# '138.617'

# %%
data["MRData"]["CircuitTable"]["Circuits"][0]["url"]    #Ruta para url
# Out:
# 'https://en.wikipedia.org/wiki/Adelaide_Street_Circuit'
